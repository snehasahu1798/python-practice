# %% [raw]
# __name__ : It is a method which checks wheather the code is executed as program or module

# %% [raw]
# __main__ : It is a method which checks the program executed as a individula program then the value of this variable is __main__

# %%
def f1():
    if __name__ == '__main__':
        print("The code is executed as program")
    else:
        print("The code is executed as module")

print(f1())
# Out:
# The code is executed as program
# None
