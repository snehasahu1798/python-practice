# %% [raw]
# Python provides the inbuilt module math

# %%
from math import *

# %%
print(sqrt(4)) #square root
# Out:
# 2.0

# %%
print(ceil(10.1)) #round off
# Out:
# 11

# %%
print(floor(10.1)) #remove decimal
# Out:
# 10

# %%
print(fabs(-10.6)) #convert into positive number
# Out:
# 10.6

# %%
print(fabs(10)) #remains positive number also makes as a float
# Out:
# 10.0
